# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the CSV file into a DataFrame
df_top_paying_skills = pd.read_csv('../csv_files_datapull/4_top_paying_skills.csv')
df_top_paying_skills.head(10)
# Out:
#     skills  avg_salary_$
# 0      aws       136,437
# 1    azure       133,436
# 2   python       132,345
# 3      sql       126,367
# 4  tableau       115,394

# %%
# Sort by average salary descending and reset index
df_sorted = df_top_paying_skills.sort_values(by='avg_salary_$', ascending=False)

# Name Variables
skill_name = df_sorted['skills']
average_salary = df_sorted['avg_salary_$']
bar_color = '#8E4585'

plt.bar(skill_name, average_salary, color=bar_color)
plt.title('Top Paying Skills based on Salary (2025)')
plt.xlabel('Skill')
plt.ylabel('Average Salary ($)')
plt.ylim(0, 150000)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Prevent label cutoff
plt.show()
